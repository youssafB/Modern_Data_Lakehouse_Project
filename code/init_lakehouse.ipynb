# %% [markdown]
# # DATA LAKEHOUSE INITIALIZATION NOTEBOOK
#
# - **Purpose:** Sets up the three-tier medallion architecture (Bronze/Silver/Gold)
#   for the data lakehouse with catalog, schemas, and storage volumes
# - **Author:** Youssef Bouraha
# - **Date:** 18/01/2026

# %% [markdown]
# # 1. Select Catalog

# %%
# %sql
USE CATALOG workspace;

# %% [markdown]
# # 2. Create Lakehouse Schemas

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS bronze
COMMENT 'Bronze layer: raw ingested data';

CREATE SCHEMA IF NOT EXISTS silver
COMMENT 'Silver layer: cleaned and transformed data';

CREATE SCHEMA IF NOT EXISTS gold
COMMENT 'Gold layer: business-ready data';

# %% [markdown]
# # 3. Create Volume

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.bronze.raw_sources
COMMENT 'Volume for raw source files (CSV)';
